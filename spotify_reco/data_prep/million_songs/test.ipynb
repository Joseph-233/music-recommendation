# %%
import songs10k as s10
import pandas as pd

# %%
pd.DataFrame(s10.read("../../datasets/million_songs/MillionSong10000Subset/all.h5",50))
# Out:
# number of songs in this file: 50
# 'Cols' object has no attribute 'idx_artist_mbtags'
# 'Cols' object has no attribute 'idx_artist_mbtags'
# Read song 0 / 49 from file: ../../datasets/million_songs/MillionSong10000Subset/all.h5
# 'Cols' object has no attribute 'idx_artist_mbtags'
# 'Cols' object has no attribute 'idx_artist_mbtags'
# Read song 1 / 49 from file: ../../datasets/million_songs/MillionSong10000Subset/all.h5
# 'Cols' object has no attribute 'idx_artist_mbtags'
# 'Cols' object has no attribute 'idx_artist_mbtags'
# Read song 2 / 49 from file: ../../datasets/million_songs/MillionSong10000Subset/all.h5
# 'Cols' object has no attribute 'idx_artist_mbtags'
# 'Cols' object has no attribute 'idx_artist_mbtags'
# Read song 3 / 49 from file: ../../datasets/million_songs/MillionSong10000Subset/all.h5
# 'Cols' object has no attribute 'idx_artist_mbtags'
# 'Cols' object has no attribute 'idx_artist_mbtags'
# ...
