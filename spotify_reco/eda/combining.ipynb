# %%
import pandas as pd
# Out:
# /var/folders/2d/3hctyjd51cn5wc76s6w7g2d00000gn/T/ipykernel_46062/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.DataFrame()
for i in range(1, 10):
    df_temp = pd.read_csv(f'./spotify_data_chunk_{i}.csv')
    df = pd.concat([df, df_temp])
    print(df.shape)
    df.head()
# Out:
# (1000, 26)
# (2000, 26)
# (3000, 26)
# (4000, 26)
# (5000, 26)
# (6000, 26)
# (7000, 26)
# (8000, 26)
# (9000, 26)

# %%
df.head()
# Out:
#                                        user                song  \
# 0  a4f803a42f03018ccfa4c8a27e330df40be8b9b9  SOPSOHT12A67AE0235
# 1  0878045f0dc2968f0403a26e6fd8bda99d19d0db  SOXIGHW12A6D4F7245
# 2  2bd8c53931b30461ecf79469c12099a5e25f6618  SOAZTAD12A8C14494A
# 3  1adcd0137fabfe2c9b2828caf5b1c95bf7994337  SODTEIO12A8AE46F47
# 4  e8a55ac62f27b90294c126358ef5409b6a341fcd  SOWSEEJ12AB01893F4
#
#                                  title  play_count  \
# 0                                Almaz           1
# 1                    Weak In The Knees           2
# 2                     Until We're Dead           1
# 3                          Gas Can Row           1
# 4  Everything Looks Beautiful On Video           5
#
#                           release            artist_name  year  \
# 0              Every Kind Of Mood         Randy Crawford  1986
# 1  If Your Memory Serves You Well           Serena Ryder  2006
# 2                Until We're Dead  Star Fucking Hipsters  2008
# 3                       Head Home                O'Death  2007
# 4                 Stop The Future            The Epoxies  2005
#
#                                               genres  danceability  energy  \
# 0                                 disco, smooth jazz         0.694   0.637
# 1  canadian indie, canadian pop, canadian singer-...         0.613   0.710
# 2        crack rock steady, folk punk, ska, ska punk         0.251   0.933
# 3                                                NaN           NaN     NaN
# 4                      portland punk, power-pop punk         0.444   0.894
#
#    ...  liveness  valence    tempo            type                      id  \
# 0  ...    0.1290    0.397  136.007  audio_features  2fbTbfyhKAb3sKySsTeOy9
# 1  ...    0.1200    0.401  141.987  audio_features  1xebBdGOBa4vg3a4PvPiar
# 2  ...    0.0849    0.140  114.711  audio_features  4lfZ5fgY8XALDoKBwErce0
# 3  ...       NaN      NaN      NaN             NaN                     NaN
# 4  ...    0.4050    0.637  175.938  audio_features  5oMMBaq00zNkDXV3zuTO6G
#
#                                     uri  \
# 0  spotify:track:2fbTbfyhKAb3sKySsTeOy9
# 1  spotify:track:1xebBdGOBa4vg3a4PvPiar
# 2  spotify:track:4lfZ5fgY8XALDoKBwErce0
# 3                                   NaN
# 4  spotify:track:5oMMBaq00zNkDXV3zuTO6G
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2fbTbfyhKAb3...
# 1  https://api.spotify.com/v1/tracks/1xebBdGOBa4v...
# 2  https://api.spotify.com/v1/tracks/4lfZ5fgY8XAL...
# 3                                                NaN
# 4  https://api.spotify.com/v1/tracks/5oMMBaq00zNk...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2fbT...     270773.0
# 1  https://api.spotify.com/v1/audio-analysis/1xeb...     220733.0
# 2  https://api.spotify.com/v1/audio-analysis/4lfZ...     237093.0
# 3                                                NaN          NaN
# 4  https://api.spotify.com/v1/audio-analysis/5oMM...     183760.0
#
#   time_signature
# 0            4.0
# 1            4.0
# 2            4.0
# 3            NaN
# 4            4.0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['user', 'song', 'title', 'play_count', 'release', 'artist_name', 'year',
#        'genres', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df.drop(columns=['uri', 'track_href', 'analysis_url',
       'duration_ms', 'time_signature', 'type'], inplace=True)

# %%
df.to_csv('../popular_songs_metadata_combined.csv', index=False)
