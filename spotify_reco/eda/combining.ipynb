# %%
import pandas as pd

# %%
df = pd.DataFrame()
for i in range(1, 11):
    if i == 7: 
        continue
    df_temp = pd.read_csv(f'/Users/gretalerer/Desktop/music-recommendation/spotify_reco/eda/spotify_data_chunk_{i}.csv')
    df = pd.concat([df, df_temp])
    print(df.shape)
    df.head()
# Out:
# (1000, 26)
# (2000, 26)
# (3000, 26)
# (4000, 26)
# (5000, 26)
# (6000, 26)
# (7000, 26)
# (8000, 26)
# (9000, 26)

# %%
df.head()
# Out:
#                                        user                song      title  \
# 0  b493eda768d25cfb48dec2567b0826cdb9f6eef4  SOCBSZW12AB01891C1       XRDS
# 1  d50046ceb4db11dc162649a0da27733ff5194b47  SOAAAGQ12A8C1420C8  Orgelblut
# 2  1e93ab57208a575ad87872ff3a25c1743632d0a1  SOAAAGQ12A8C1420C8  Orgelblut
# 3  a0846981ab7c3d06cf1d966e7109774e306eb61a  SOAAAGQ12A8C1420C8  Orgelblut
# 4  6e8d4e7d986e077d334da41638e63b9030710141  SOAAAGQ12A8C1420C8  Orgelblut
#
#    play_count       release                artist_name  year  \
# 0         256  Ritual Noise                   Covenant     0
# 1           1       Dolores  Bohren & Der Club Of Gore  2008
# 2           1       Dolores  Bohren & Der Club Of Gore  2008
# 3           1       Dolores  Bohren & Der Club Of Gore  2008
# 4           1       Dolores  Bohren & Der Club Of Gore  2008
#
#                                               genres  danceability  energy  \
# ...

# %%
df.columns
# Out:
# Index(['user', 'song', 'title', 'play_count', 'release', 'artist_name', 'year',
#        'genres', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df.drop(columns=['uri', 'track_href', 'analysis_url',
       'duration_ms', 'time_signature', 'type'], inplace=True)

# %%
df.to_csv('/Users/gretalerer/Desktop/music-recommendation/spotify_reco/popular_songs_metadata.csv', index=False)
